# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 10)

# %%
# Loads the dataframes
vancouver_date = pd.read_csv('Vancouver_Date_Final.csv')
denver_date = pd.read_csv('Denver_Date_Final.csv')

# %%
vancouver_date
# Out:
#         Date-key Day-of-week  Minute  Hour  Day  Month  Year  Weekend  \
# 0            100    Thursday       6     2    7      3  2019    False
# 1            101     Tuesday      12     4   27      8  2019    False
# ...          ...         ...     ...   ...  ...    ...   ...      ...
# 193376    193476    Saturday      22    16    4      8  2018     True
# 193377    193477      Monday      11    18   20      6  2016    False
#
#         Holiday Holiday-name
# 0         False          NaN
# 1         False          NaN
# ...         ...          ...
# 193376    False          NaN
# 193377    False          NaN
#
# [193378 rows x 10 columns]

# %%
denver_date
# Out:
#         Date-key Day-of-week  Minute  Hour  Day  Month  Year  Weekend  \
# 0         193478   Wednesday      31    23   15      6  2016    False
# 1         193479   Wednesday      30    12   11     10  2017    False
# ...          ...         ...     ...   ...  ...    ...   ...      ...
# 462403    655881    Saturday      20    17   16     11  2019     True
# 462404    655882      Friday      45     6   27     12  2019    False
#
#         Holiday Holiday-name
# 0         False          NaN
# 1         False          NaN
# ...         ...          ...
# 462403    False          NaN
# 462404    False          NaN
#
# [462405 rows x 10 columns]

# %%
vancouver_date.shape[0] + denver_date.shape[0]
# Out:
# 655783

# %%
# Meges the dataframes
merged_date_df = pd.concat([vancouver_date, denver_date], ignore_index=True, sort=True) # Concatenates both tables

# %%
merged_date_df
# Out:
#         Date-key  Day Day-of-week  Holiday Holiday-name  Hour  Minute  Month  \
# 0            100    7    Thursday    False          NaN     2       6      3
# 1            101   27     Tuesday    False          NaN     4      12      8
# ...          ...  ...         ...      ...          ...   ...     ...    ...
# 655781    655881   16    Saturday    False          NaN    17      20     11
# 655782    655882   27      Friday    False          NaN     6      45     12
#
#         Weekend  Year
# 0         False  2019
# 1         False  2019
# ...         ...   ...
# 655781     True  2019
# 655782    False  2019
#
# [655783 rows x 10 columns]

# %%
merged_date_df.to_csv('Merged_Date_Final.csv', index=False)
