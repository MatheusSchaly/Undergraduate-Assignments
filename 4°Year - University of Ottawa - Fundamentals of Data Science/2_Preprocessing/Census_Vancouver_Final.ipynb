# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 4)

# %%
df = pd.read_csv("Census_Vancouver.csv")

# %%
# Organizes the into the right columns
df = df.iloc[3:28]
df.columns = df.iloc[0]
df.drop(df.index[0], inplace=True)
df.rename(columns={'Arbutus-Ridge': 'Arbutus Ridge'})
df.drop(['Vancouver CSD (City)', 'CMA of Vancouver'], axis=1, inplace=True)

# %%
df
# Out:
# 3                              NaN Arbutus-Ridge  Downtown Dunbar-Southlands  \
# 4   Total population by age groups       15,910    54,690            21,745
# 5                    0 to 4 years           570     1,840               930
# ..                             ...           ...       ...               ...
# 26                 80 to 84 years           535       565               405
# 27               85 years and over          785        450               425
#
# 3   Fairview Grandview-Woodland Hastings-Sunrise Kensington-Cedar Cottage  \
# 4    31,445             27,305           33,990                   47,470
# 5     1,080              1,190            1,625                    2,440
# ..       ...                ...              ...                      ...
# 26      665                490              885                      965
# 27       880                350              685                      785
#
# ...

# %%
df.to_csv("Census_Vancouver_Changed.csv", index=False)
